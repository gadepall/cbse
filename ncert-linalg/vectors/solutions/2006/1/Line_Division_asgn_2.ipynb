# %% [markdown]
# <a href="https://colab.research.google.com/github/Padmanabhk1/Assignment-2/blob/main/Line_Division_asgn_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""Line.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1c-PtsmmEBdysbi-9Urx63pTqnNLRxocZ
"""

import numpy as np
import matplotlib.pyplot as plt
import numpy.linalg as LA

plt.axis([0,3,2,8])

plt.axis('on')
plt.grid(True)

A = np.array([1,3])
B = np.array([2,7])
P = np.array([10/7,33/7])

def line_gen(A,B):
  len =10
  dim = A.shape[0]
  x_AB = np.zeros((dim,len))
  lam_1 = np.linspace(0,1,len)
  for i in range(len):
    temp1 = A + lam_1[i]*(B-A)
    x_AB[:,i]= temp1.T
  return x_AB

  #Generating all lines
x_AP = line_gen(A,P)
x_PB = line_gen(P,B)

#Plotting all lines
plt.plot(x_AP[0,:],x_AP[1,:],label='$AP$')
plt.plot(x_PB[0,:],x_PB[1,:],label='$PB$')

plt.text(1,3,'A(1,3)')
plt.text(2,7,'B(2,7)')
plt.text(10/7,33/7,'P(10/7,33/7)')

plt.savefig('line division.png')
plt.show()
